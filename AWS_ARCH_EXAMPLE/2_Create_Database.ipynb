# %% [markdown]
# # Create PostgreSQL RDS Instance
# https://docs.aws.amazon.com/AmazonRDS/latest/UserGuide/CHAP_GettingStarted.CreatingConnecting.PostgreSQL.html

# %%
# !aws rds create-db-instance \
--db-name ExampleDB \
--engine MySQL \
--db-instance-identifier MySQLForLambdaTest \
--backup-retention-period 3 \
--db-instance-class db.t2.micro \
--allocated-storage 5 \
--db-subnet-group-name default-vpc-02278264603d15874 \
--no-publicly-accessible \
--master-username username \
--master-user-password password
# Out:
# {
#     "DBInstance": {
#         "DBInstanceIdentifier": "mysqlforlambdatest",
#         "DBInstanceClass": "db.t2.micro",
#         "Engine": "mysql",
#         "DBInstanceStatus": "creating",
#         "MasterUsername": "username",
#         "DBName": "ExampleDB",
#         "AllocatedStorage": 5,
#         "PreferredBackupWindow": "05:47-06:17",
#         "BackupRetentionPeriod": 3,
#         "DBSecurityGroups": [],
#         "VpcSecurityGroups": [
#             {
#                 "VpcSecurityGroupId": "sg-099e148852cd6f1bd",
#                 "Status": "active"
#             }
#         ],
#         "DBParameterGroups": [
#             {
#                 "DBParameterGroupName": "default.mysql5.7",
#                 "ParameterApplyStatus": "in-sync"
#             }
#         ],
#         "DBSubnetGroup": {
#             "DBSubnetGroupName": "default-vpc-02278264603d15874",
#             "DBSubnetGroupDescription": "Created from the RDS Management Console",
#             "VpcId": "vpc-02278264603d15874",
#             "SubnetGroupStatus": "Complete",
#             "Subnets": [
#                 {
#                     "SubnetIdentifier": "subnet-052daa0285540fc3e",
#                     "SubnetAvailabilityZone": {
#                         "Name": "us-east-1a"
#                     },
#                     "SubnetStatus": "Active"
#                 },
#                 {
#                     "SubnetIdentifier": "subnet-015727aff916cadfe",
#                     "SubnetAvailabilityZone": {
#                         "Name": "us-east-1e"
#                     },
#                     "SubnetStatus": "Active"
#                 },
#                 {
#                     "SubnetIdentifier": "subnet-00e8f4be87ef6f62f",
#                     "SubnetAvailabilityZone": {
#                         "Name": "us-east-1d"
#                     },
#                     "SubnetStatus": "Active"
#                 },
#                 {
#                     "SubnetIdentifier": "subnet-0a23c0885f26d2850",
#                     "SubnetAvailabilityZone": {
#                         "Name": "us-east-1b"
#                     },
#                     "SubnetStatus": "Active"
#                 },
#                 {
#                     "SubnetIdentifier": "subnet-0da9b16fcf3598928",
#                     "SubnetAvailabilityZone": {
#                         "Name": "us-east-1c"
#                     },
#                     "SubnetStatus": "Active"
#                 },
#                 {
#                     "SubnetIdentifier": "subnet-0882102fc58f142bb",
#                     "SubnetAvailabilityZone": {
#                         "Name": "us-east-1f"
#                     },
#                     "SubnetStatus": "Active"
#                 }
#             ]
#         },
#         "PreferredMaintenanceWindow": "sun:07:07-sun:07:37",
#         "PendingModifiedValues": {
#             "MasterUserPassword": "****"
#         },
#         "MultiAZ": false,
#         "EngineVersion": "5.7.22",
#         "AutoMinorVersionUpgrade": true,
#         "ReadReplicaDBInstanceIdentifiers": [],
#         "LicenseModel": "general-public-license",
#         "OptionGroupMemberships": [
#             {
#                 "OptionGroupName": "default:mysql-5-7",
#                 "Status": "in-sync"
#             }
#         ],
#         "PubliclyAccessible": false,
#         "StorageType": "gp2",
#         "DbInstancePort": 0,
#         "StorageEncrypted": false,
#         "DbiResourceId": "db-M3MMMCYOP4GYKBOORDISVBFURA",
#         "CACertificateIdentifier": "rds-ca-2015",
#         "DomainMemberships": [],
#         "CopyTagsToSnapshot": false,
#         "MonitoringInterval": 0,
#         "DBInstanceArn": "arn:aws:rds:us-east-1:211745082496:db:mysqlforlambdatest",
#         "IAMDatabaseAuthenticationEnabled": false,
#         "PerformanceInsightsEnabled": false,
#         "DeletionProtection": false,
#         "AssociatedRoles": []
#     }
# }

# %%
# !aws rds create-db-instance \
--db-name arch_db \
--engine PostGres \
--db-instance-identifier arch-db \
--backup-retention-period 3 \
--db-instance-class db.t2.micro \
--allocated-storage 20 \
--db-subnet-group-name default-vpc-02278264603d15874 \
--no-publicly-accessible \
--master-username username \
--master-user-password password
# Out:
# {
#     "DBInstance": {
#         "DBInstanceIdentifier": "arch-db",
#         "DBInstanceClass": "db.t2.micro",
#         "Engine": "postgres",
#         "DBInstanceStatus": "creating",
#         "MasterUsername": "username",
#         "DBName": "arch_db",
#         "AllocatedStorage": 20,
#         "PreferredBackupWindow": "03:27-03:57",
#         "BackupRetentionPeriod": 3,
#         "DBSecurityGroups": [],
#         "VpcSecurityGroups": [
#             {
#                 "VpcSecurityGroupId": "sg-099e148852cd6f1bd",
#                 "Status": "active"
#             }
#         ],
#         "DBParameterGroups": [
#             {
#                 "DBParameterGroupName": "default.postgres11",
#                 "ParameterApplyStatus": "in-sync"
#             }
#         ],
#         "DBSubnetGroup": {
#             "DBSubnetGroupName": "default-vpc-02278264603d15874",
#             "DBSubnetGroupDescription": "Created from the RDS Management Console",
#             "VpcId": "vpc-02278264603d15874",
#             "SubnetGroupStatus": "Complete",
#             "Subnets": [
#                 {
#                     "SubnetIdentifier": "subnet-052daa0285540fc3e",
#                     "SubnetAvailabilityZone": {
#                         "Name": "us-east-1a"
#                     },
#                     "SubnetStatus": "Active"
#                 },
#                 {
#                     "SubnetIdentifier": "subnet-015727aff916cadfe",
#                     "SubnetAvailabilityZone": {
#                         "Name": "us-east-1e"
#                     },
#                     "SubnetStatus": "Active"
#                 },
#                 {
#                     "SubnetIdentifier": "subnet-00e8f4be87ef6f62f",
#                     "SubnetAvailabilityZone": {
#                         "Name": "us-east-1d"
#                     },
#                     "SubnetStatus": "Active"
#                 },
#                 {
#                     "SubnetIdentifier": "subnet-0a23c0885f26d2850",
#                     "SubnetAvailabilityZone": {
#                         "Name": "us-east-1b"
#                     },
#                     "SubnetStatus": "Active"
#                 },
#                 {
#                     "SubnetIdentifier": "subnet-0da9b16fcf3598928",
#                     "SubnetAvailabilityZone": {
#                         "Name": "us-east-1c"
#                     },
#                     "SubnetStatus": "Active"
#                 },
#                 {
#                     "SubnetIdentifier": "subnet-0882102fc58f142bb",
#                     "SubnetAvailabilityZone": {
#                         "Name": "us-east-1f"
#                     },
#                     "SubnetStatus": "Active"
#                 }
#             ]
#         },
#         "PreferredMaintenanceWindow": "fri:06:04-fri:06:34",
#         "PendingModifiedValues": {
#             "MasterUserPassword": "****"
#         },
#         "MultiAZ": false,
#         "EngineVersion": "11.5",
#         "AutoMinorVersionUpgrade": true,
#         "ReadReplicaDBInstanceIdentifiers": [],
#         "LicenseModel": "postgresql-license",
#         "OptionGroupMemberships": [
#             {
#                 "OptionGroupName": "default:postgres-11",
#                 "Status": "in-sync"
#             }
#         ],
#         "PubliclyAccessible": false,
#         "StorageType": "gp2",
#         "DbInstancePort": 0,
#         "StorageEncrypted": false,
#         "DbiResourceId": "db-5KBZRJFETDNGXMIFUECYAWXTFQ",
#         "CACertificateIdentifier": "rds-ca-2015",
#         "DomainMemberships": [],
#         "CopyTagsToSnapshot": false,
#         "MonitoringInterval": 0,
#         "DBInstanceArn": "arn:aws:rds:us-east-1:211745082496:db:arch-db",
#         "IAMDatabaseAuthenticationEnabled": false,
#         "PerformanceInsightsEnabled": false,
#         "DeletionProtection": false,
#         "AssociatedRoles": []
#     }
# }

# %%
# !pg
